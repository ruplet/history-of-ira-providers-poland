# %%
import pandas as pd

# %%
df = pd.read_excel('pl-sources-ike-ikze-knf/IKE_lista_podmioty_30062017_58489.xls')

# %%
df
# Out:
#    Lista instytucji finansowych prowadzących IKE według stanu na dzień 30 czerwca 2017 r.  \
# 0                                                 NaN
# 1                                                 NaN
# 2                      ZAKŁADY UBEZPIECZEŃ NA ŻYCIE:
# 3                                                 NaN
# 4                                                  1.
# ..                                                ...
# 66                                                NaN
# 67                                                 1.
# 68                                                 2.
# 69                                                 3.
# 70                                                 4.
#
#                         Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                              NaN         NaN         NaN         NaN
# 1                              NaN         NaN         NaN         NaN
# ...
